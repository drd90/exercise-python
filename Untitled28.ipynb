# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
df_2 = pd.read_csv(path)
df_2.head()
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %%
df_2 = df_2[['Launch Site', 'Lat', 'Long', 'class']]

# %%
df_2.head()
# Out:
#    Launch Site        Lat       Long  class
# 0  CCAFS LC-40  28.562302 -80.577356      0
# 1  CCAFS LC-40  28.562302 -80.577356      0
# 2  CCAFS LC-40  28.562302 -80.577356      0
# 3  CCAFS LC-40  28.562302 -80.577356      0
# 4  CCAFS LC-40  28.562302 -80.577356      0

# %%
launchsites = df_2.groupby(['Launch Site'], as_index= False).first()

# %%
launchsites = launchsites[['Launch Site', 'Lat', 'Long']]
launchsites
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
# Keep your DataFrame called launch_sites (don't overwrite it)

# Create the map
mymap = folium.Map(location=[launchsites.Lat.mean(), launchsites.Long.mean()], zoom_start=5)

# Create a FeatureGroup (use a new name to avoid overwriting)
launch_fg = folium.FeatureGroup(name="Launch Sites")

# Loop through the DataFrame and add markers
for Lat, Long in zip(launchsites.Lat, launchsites.Long):
    launch_fg.add_child(
        folium.vector_layers.CircleMarker(
            [Lat, Long],
            radius=5,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )

# Add feature group to the map
mymap.add_child(launch_fg)

# Display map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5b732e891d2bfe5b1012a42a42020bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5b732e891d2bfe5b1012a42a42020bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5b732e891d2bfe5b1012a42a42020bf = L.map(
#                 &quot;map_d5b732e891d2bfe5b1012a42a42020bf&quot;,
#                 {
#                     center: [30.08289697, -90.602954325],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcbdf9244f0a10b3dbff0d38c8d521cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcbdf9244f0a10b3dbff0d38c8d521cd.addTo(map_d5b732e891d2bfe5b1012a42a42020bf);
#
#
#             var feature_group_dc0e89b2293afe59a6028cba2f26ecf3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_3e603664770aa4456012eb4896fbfff8 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc0e89b2293afe59a6028cba2f26ecf3);
#
#
#             var circle_marker_46eb33249cc4cda638e8511eed47b6bd = L.circleMarker(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc0e89b2293afe59a6028cba2f26ecf3);
#
#
#             var circle_marker_f504b2ca0c0ef5deec2b90e9a179914d = L.circleMarker(
#                 [28.57325457, -80.64689529],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc0e89b2293afe59a6028cba2f26ecf3);
#
#
#             var circle_marker_0e59e4a5e803595dab99cb145ae2fb57 = L.circleMarker(
#                 [34.63283416, -120.6107455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc0e89b2293afe59a6028cba2f26ecf3);
#
#
#             feature_group_dc0e89b2293afe59a6028cba2f26ecf3.addTo(map_d5b732e891d2bfe5b1012a42a42020bf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_2.columns
# Out:
# Index(['Flight Number', 'Date', 'Time (UTC)', 'Booster Version', 'Launch Site',
#        'Payload', 'Payload Mass (kg)', 'Orbit', 'Customer', 'Landing Outcome',
#        'class', 'Lat', 'Long'],
#       dtype='object')

# %%
df_2.rename(columns = {'Landing Outcome':'Landing_Outcome'}, inplace= True)

# %%
df = df_2[['Launch Site', 'Lat', 'Long', 'class', 'Landing_Outcome']]
df.head()
# Out:
#    Launch Site        Lat       Long  class        Landing_Outcome
# 0  CCAFS LC-40  28.562302 -80.577356      0  Failure   (parachute)
# 1  CCAFS LC-40  28.562302 -80.577356      0  Failure   (parachute)
# 2  CCAFS LC-40  28.562302 -80.577356      0             No attempt
# 3  CCAFS LC-40  28.562302 -80.577356      0             No attempt
# 4  CCAFS LC-40  28.562302 -80.577356      0             No attempt

# %%
# Keep your DataFrame called launch_sites (don't overwrite it)

# Create the map
mymap = folium.Map(location=[df.Lat.mean(), df.Long.mean()], zoom_start=5)

# Create a FeatureGroup (use a new name to avoid overwriting)
outcome = folium.FeatureGroup(name="Landing_Outcome")

# Loop through the DataFrame and add markers
for Lat, Long in zip(df.Lat, df.Long):
    outcome.add_child(
        folium.vector_layers.CircleMarker(
            [Lat, Long],
            radius=5,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )

latitudes = list(df.Lat)
longitudes = list(df.Long)
labels = list(df.Landing_Outcome)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(mymap) 

# Add feature group to the map
mymap.add_child(outcome)

# Display map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f44b7c2f30235fb9be30cdc088fdf08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f44b7c2f30235fb9be30cdc088fdf08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f44b7c2f30235fb9be30cdc088fdf08 = L.map(
#                 &quot;map_8f44b7c2f30235fb9be30cdc088fdf08&quot;,
#                 {
#                     center: [29.648980044464285, -87.74225182964287],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_903adcbba41abed374c01f8296630392 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_903adcbba41abed374c01f8296630392.addTo(map_8f44b7c2f30235fb9be30cdc088fdf08);
#
#
#             var marker_6bca0168e6943221d06bb300ebb22aa4 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_8f44b7c2f30235fb9be30cdc088fdf08);
#
#
#         var popup_031b8c157e69ac3d10493335e53394af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e60093b3c703c52bd73144b58f22f243 = $(`&lt;div id=&quot;html_e60093b3c703c52bd73144b58f22f243&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Failure   (parachute)&lt;/div&gt;`)[0];
#                 popup_031b8c157e69ac3d10493335e53394af.setContent(html_e60093b3c703c52bd73144b58f22f243);
#
#
#
#         marker_6bca0168e6943221d06bb300ebb22aa4.bindPopup(popup_031b8c157e69ac3d10493335e53394af)
#         ;
#
#
#
#
#             var marker_29117f1cefef9e367b616b057417c97b = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_8f44b7c2f30235fb9be30cdc088fdf08);
#
#
#         var popup_05dc5976a870df4fffe050b5ed9f3439 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da41f797f35d2eca51db4a12354c8632 = $(`&lt;div id=&quot;html_da41f797f35d2eca51db4a12354c8632&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Failure   (parachute)&lt;/div&gt;`)[0];
#                 popup_05dc5976a870df4fffe050b5ed9f3439.setContent(html_da41f797f35d2eca51db4a12354c8632);
#
#
#
#         marker_29117f1cefef9e367b616b057417c97b.bindPopup(popup_05dc5976a870df4fffe050b5ed9f3439)
#         ;
#
#
#
#
#             var marker_8fa1171d6eaacd14d0cbd7ae4f598942 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_8f44b7c2f30235fb9be30cdc088fdf08);
#
#
#         var popup_fb6a93640a6cae4586a2de275bf7400b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c28981896cc1163672ff3c1dd1a31619 = $(`&lt;div id=&quot;html_c28981896cc1163672ff3c1dd1a31619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No attempt&lt;/div&gt;`)[0];
#                 popup_fb6a93640a6cae4586a2de275bf7400b.setContent(html_c28981896cc1163672ff3c1dd1a31619);
#
#
#
#         marker_8fa1171d6eaacd14d0cbd7ae4f598942.bindPopup(popup_fb6a93640a6cae4586a2de275bf7400b)
#         ;
#
#
#
#
#             var marker_3fca75bd36e94336e9979900cb51e459 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_8f44b7c2f30235fb9be30cdc088fdf08);
#
#
#         var popup_58abdb29fe7f991c16533b3b50dfb4fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a243db05e4b7899b38246f7c5a604b19 = $(`&lt;div id=&quot;html_a243db05e4b7899b38246f7c5a604b19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No attempt&lt;/div&gt;`)[0];
#                 popup_58abdb29fe7f991c16533b3b50dfb4fe.setContent(html_a243db05e4b7899b38246f7c5a604b19);
#
#
#
#         marker_3fca75bd36e94336e9979900cb51e459.bindPopup(popup_58abdb29fe7f991c16533b3b50dfb4fe)
#         ;
#
#
#
#
#             var marker_fa9366f8067e2b83f5fc6ccf75b28360 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_8f44b7c2f30235fb9be30cdc088fdf08);
#
#
#         var popup_2a80654dfae393692ecf12c5fdd6b23b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4221aa9a82e25344652836cc380a5499 = $(`&lt;div id=&quot;html_4221aa9a82e25344652836cc380a5499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No attempt&lt;/div&gt;`)[0];
#                 popup_2a80654dfae393692ecf12c5fdd6b23b.setContent(html_4221aa9a82e25344652836cc3

# %%
df.shape
# Out:
# (56, 5)

# %%
df.head()
# Out:
#    Launch Site        Lat       Long  class        Landing_Outcome
# 0  CCAFS LC-40  28.562302 -80.577356      0  Failure   (parachute)
# 1  CCAFS LC-40  28.562302 -80.577356      0  Failure   (parachute)
# 2  CCAFS LC-40  28.562302 -80.577356      0             No attempt
# 3  CCAFS LC-40  28.562302 -80.577356      0             No attempt
# 4  CCAFS LC-40  28.562302 -80.577356      0             No attempt

# %%
print(df['Lat'].unique())
print(df['Long'].unique())
# Out:
# [28.56230197 34.63283416 28.57325457 28.56319718]
# [ -80.57735648 -120.6107455   -80.64689529  -80.57682003]

# %%
df[['Launch Site', 'Lat', 'Long']].value_counts()
# Out:
# Launch Site   Lat        Long
# CCAFS LC-40   28.562302  -80.577356     26
# KSC LC-39A    28.573255  -80.646895     13
# VAFB SLC-4E   34.632834  -120.610745    10
# CCAFS SLC-40  28.563197  -80.576820      7
# Name: count, dtype: int64

# %%
import folium

# Criar o mapa centralizado na média das localizações
mymap = folium.Map(location=[df.Lat.mean(), df.Long.mean()], zoom_start=5)

# Criar o FeatureGroup
outcome = folium.FeatureGroup(name="Landing Outcomes")

# Adicionar marcadores com círculos e popups
for lat, lng, label in zip(df.Lat, df.Long, df.Landing_Outcome):
    outcome.add_child(
        folium.CircleMarker(
            location=[lat, lng],
            radius=5,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
            popup=folium.Popup(label, parse_html=True)
        )
    )

# Adicionar o grupo ao mapa
mymap.add_child(outcome)

# Adicionar controle de camadas (opcional)
mymap.add_child(folium.LayerControl())

# Exibir o mapa
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d39af644264c4f933981854e9dda4690 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d39af644264c4f933981854e9dda4690&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d39af644264c4f933981854e9dda4690 = L.map(
#                 &quot;map_d39af644264c4f933981854e9dda4690&quot;,
#                 {
#                     center: [29.648980044464285, -87.74225182964287],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ef020143835646f36ff19df2324cb54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ef020143835646f36ff19df2324cb54.addTo(map_d39af644264c4f933981854e9dda4690);
#
#
#             var feature_group_e39271acc946039d8be9e125f580dd07 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_8507b95aaa9304da4339d5696ddfa95a = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e39271acc946039d8be9e125f580dd07);
#
#
#         var popup_25a0a76a969d3b0934d31f2b1dd79283 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e81e73d48dd412f1978c0c9fb8b048c4 = $(`&lt;div id=&quot;html_e81e73d48dd412f1978c0c9fb8b048c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Failure   (parachute)&lt;/div&gt;`)[0];
#                 popup_25a0a76a969d3b0934d31f2b1dd79283.setContent(html_e81e73d48dd412f1978c0c9fb8b048c4);
#
#
#
#         circle_marker_8507b95aaa9304da4339d5696ddfa95a.bindPopup(popup_25a0a76a969d3b0934d31f2b1dd79283)
#         ;
#
#
#
#
#             var circle_marker_681fd3dc83dfc7da90c8f340b36e3772 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e39271acc946039d8be9e125f580dd07);
#
#
#         var popup_46023bcfab8c61c203e4206779e1fc66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b42a3930d10a607bc373f477ccb5d520 = $(`&lt;div id=&quot;html_b42a3930d10a607bc373f477ccb5d520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Failure   (parachute)&lt;/div&gt;`)[0];
#                 popup_46023bcfab8c61c203e4206779e1fc66.setContent(html_b42a3930d10a607bc373f477ccb5d520);
#
#
#
#         circle_marker_681fd3dc83dfc7da90c8f340b36e3772.bindPopup(popup_46023bcfab8c61c203e4206779e1fc66)
#         ;
#
#
#
#
#             var circle_marker_7def88f1ebe8adb30a491a5f1599fad1 = L.circleMarker(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e39271acc946039d8be9e125f580dd07);
#
#
#         var popup_6d841451ae4b91969956605123ffbf5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c88a5553ffb4774a2d0190a0bb7baeb = $(`&lt;div id=&quot;html_2c88a5553ffb4774a2d0190a0bb7baeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No attempt&lt;/div&gt;`)[0];
#                 popup_6d841451ae4b91969956605123ffbf5e.setContent(html_2c88a5553ffb4774a2d0190a0bb7baeb);

# %%
df.isnull().sum()
# Out:
# Launch Site        0
# Lat                0
# Long               0
# class              0
# Landing_Outcome    0
# dtype: int64

# %%
df_validos = df.dropna(subset=['Lat', 'Long'])
print(len(df_validos))  # Quantas linhas com coordenadas válidas
# Out:
# 56

# %%
import random

mymap = folium.Map(location=[df.Lat.mean(), df.Long.mean()], zoom_start=5)
outcome = folium.FeatureGroup(name="Landing Outcomes")

for lat, lng, label in zip(df.Lat, df.Long, df.Landing_Outcome):
    lat_j = lat + random.uniform(-0.01, 0.01)
    lng_j = lng + random.uniform(-0.01, 0.01)
    outcome.add_child(
        folium.CircleMarker(
            location=[lat_j, lng_j],
            radius=5,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6,
            popup=folium.Popup(label, parse_html=True)
        )
    )

mymap.add_child(outcome)
folium.LayerControl().add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d675101c7ac1a5f0cdc39dba38ae7f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d675101c7ac1a5f0cdc39dba38ae7f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d675101c7ac1a5f0cdc39dba38ae7f0 = L.map(
#                 &quot;map_9d675101c7ac1a5f0cdc39dba38ae7f0&quot;,
#                 {
#                     center: [29.648980044464285, -87.74225182964287],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_918b09e911f5f8a3946d50ca4e74e337 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_918b09e911f5f8a3946d50ca4e74e337.addTo(map_9d675101c7ac1a5f0cdc39dba38ae7f0);
#
#
#             var feature_group_e42b1a761b31ce8dd3b47c87df64071d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_8b9977839afa7c75d838335ef175424e = L.circleMarker(
#                 [28.556333148774875, -80.58446374393294],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e42b1a761b31ce8dd3b47c87df64071d);
#
#
#         var popup_9acaadf0e86ac826dd325af5ba47bc3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c021a3803baac57b07fa6c09502cd95e = $(`&lt;div id=&quot;html_c021a3803baac57b07fa6c09502cd95e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Failure   (parachute)&lt;/div&gt;`)[0];
#                 popup_9acaadf0e86ac826dd325af5ba47bc3e.setContent(html_c021a3803baac57b07fa6c09502cd95e);
#
#
#
#         circle_marker_8b9977839afa7c75d838335ef175424e.bindPopup(popup_9acaadf0e86ac826dd325af5ba47bc3e)
#         ;
#
#
#
#
#             var circle_marker_8bedbad2040c3d674b6a490a56ea1ed8 = L.circleMarker(
#                 [28.56703148327434, -80.58177652434047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e42b1a761b31ce8dd3b47c87df64071d);
#
#
#         var popup_24ef9eba4b06193f7fba7cb4b90b3b37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a97bcf3f8026e04a250cdf26cfed22b8 = $(`&lt;div id=&quot;html_a97bcf3f8026e04a250cdf26cfed22b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Failure   (parachute)&lt;/div&gt;`)[0];
#                 popup_24ef9eba4b06193f7fba7cb4b90b3b37.setContent(html_a97bcf3f8026e04a250cdf26cfed22b8);
#
#
#
#         circle_marker_8bedbad2040c3d674b6a490a56ea1ed8.bindPopup(popup_24ef9eba4b06193f7fba7cb4b90b3b37)
#         ;
#
#
#
#
#             var circle_marker_b840182e2772baef5bb90945497a99fa = L.circleMarker(
#                 [28.57154798148187, -80.57234395378175],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e42b1a761b31ce8dd3b47c87df64071d);
#
#
#         var popup_959189ce277349b9fa125e965bb9a6f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64e55c6aace7bb410bb86cd858d10ec3 = $(`&lt;div id=&quot;html_64e55c6aace7bb410bb86cd858d10ec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No attempt&lt;/div&gt;`)[0];
#                 popup_959189ce277349b9fa125e965bb9a6f6.setContent(html_64e55c6aace7bb410bb86cd858d1
